# %% [markdown]
# Las bases de datos empleadas son demasiado pesadas para subirlas a GitHub. Dejo los enlaces:
#
# - TMDB + IMDB Merged Movies Dataset 2024
# https://www.kaggle.com/datasets/ggtejas/tmdb-imdb-merged-movies-dataset
#
# - IMDb Name basics:
# https://datasets.imdbws.com/name.basics.tsv.gz
