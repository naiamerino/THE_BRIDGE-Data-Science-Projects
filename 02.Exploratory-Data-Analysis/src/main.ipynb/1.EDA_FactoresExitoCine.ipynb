# %% [markdown]
# 1. PREPARACIÓN DE DATASET
# He partido del dataset de películas de IMDB y TMDB https://www.kaggle.com/datasets/ggtejas/tmdb-imdb-merged-movies-dataset.
# Hice una primera limpieza en Power Query que me guardé como tmdb_imdb_limpio.csv

# %%
import pandas as pd

# %%
# Después de haber limpiado el csv en Power Query. Separador ;
df_movies = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\tmdb_imdb_limpio.csv", sep=";")

# %%
#Que haya cargado todo bien después de la transformación
df_movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 436401 entries, 0 to 436400
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      436401 non-null  int64
#  1   title                   436401 non-null  str
#  2   vote_average            436401 non-null  int64
#  3   vote_count              436401 non-null  int64
#  4   status                  436401 non-null  str
#  5   release_date            415063 non-null  str
#  6   revenue                 436401 non-null  int64
#  7   runtime                 436401 non-null  int64
#  8   adult                   436401 non-null  str
#  9   budget                  436401 non-null  int64
#  10  imdb_id                 436401 non-null  str
#  11  original_language       436401 non-null  str
#  12  original_title          436401 non-null  str
#  13  popularity              436401 non-null  int64
#  14  genre                   356728 non-null  str
#  15  production_countries.1  320678 non-null  str
#  16  production_countries.2  34815 non-null   str
#  17  director                426456 non-null  str
#  18  averageRating           436401 non-null  int64
#  19  numVotes                436401 non-null  int64
#  20  cast.1                  367599 non-null  str
#  21  cast.2                  342621 non-null  str
#  22  cast.3                  322792 non-null  str
#  23  cast.4                  302536 non-null  str
#  24  cast.5                  278739 non-null  str
#  25  cast.6                  254986 non-null  str
#  26  cast.7                  232438 non-null  str
#  27  cast.8                  211198 non-null  str
#  28  cast.9                  189946 non-null  str
#  29  cast.10                 171077 non-null  str
# dtypes: int64(9), str(21)
# memory usage: 99.9 MB

# %% [markdown]
# Nulos en género, director, país de producción... Me importan los de género porque es seguro que quiero analizar cómo impacta.

# %%
df = df_movies.dropna (subset="genre")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 356728 entries, 0 to 436400
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      356728 non-null  int64
#  1   title                   356728 non-null  str
#  2   vote_average            356728 non-null  int64
#  3   vote_count              356728 non-null  int64
#  4   status                  356728 non-null  str
#  5   release_date            351950 non-null  str
#  6   revenue                 356728 non-null  int64
#  7   runtime                 356728 non-null  int64
#  8   adult                   356728 non-null  str
#  9   budget                  356728 non-null  int64
#  10  imdb_id                 356728 non-null  str
#  11  original_language       356728 non-null  str
#  12  original_title          356728 non-null  str
#  13  popularity              356728 non-null  int64
#  14  genre                   356728 non-null  str
#  15  production_countries.1  296373 non-null  str
#  16  production_countries.2  33620 non-null   str
#  17  director                350194 non-null  str
#  18  averageRating           356728 non-null  int64
#  19  numVotes                356728 non-null  int64
#  20  cast.1                  315304 non-null  str
#  21  cast.2                  295415 non-null  str
#  22  cast.3                  279960 non-null  str
#  23  cast.4                  264165 non-null  str
#  24  cast.5                  245121 non-null  str
#  25  cast.6                  225805 non-null  str
#  26  cast.7                  207209 non-null  str
#  27  cast.8                  189480 non-null  str
#  28  cast.9                  171751 non-null  str
#  29  cast.10                 155818 non-null  str
# dtypes: int64(9), str(21)
# memory usage: 84.4 MB

# %%
#Revisar budget y revenue. Pueden no ser nulos pero ser cero es imposible
# Cuantos hay que tengan cero en presupuesto o recaudación?

print("Budget = 0:  ", (df["budget"] == 0).sum())
print("Revenue = 0: ", (df["revenue"] == 0).sum())
print("Alguno de los dos: ", ((df["budget"] == 0) | (df["revenue"] == 0)).sum())

#Pues menos mal que se me ha ocurrido mirarlo! :-(
# Me quedan 27300 pelis. Tampoco está mal
# Out:
# Budget = 0:   329340
# Revenue = 0:  340610
# Alguno de los dos:  346571

# %%
df = df [df ["budget"] != 0]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 27388 entries, 0 to 436390
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      27388 non-null  int64
#  1   title                   27388 non-null  str
#  2   vote_average            27388 non-null  int64
#  3   vote_count              27388 non-null  int64
#  4   status                  27388 non-null  str
#  5   release_date            26925 non-null  str
#  6   revenue                 27388 non-null  int64
#  7   runtime                 27388 non-null  int64
#  8   adult                   27388 non-null  str
#  9   budget                  27388 non-null  int64
#  10  imdb_id                 27388 non-null  str
#  11  original_language       27388 non-null  str
#  12  original_title          27388 non-null  str
#  13  popularity              27388 non-null  int64
#  14  genre                   27388 non-null  str
#  15  production_countries.1  23969 non-null  str
#  16  production_countries.2  4411 non-null   str
#  17  director                27303 non-null  str
#  18  averageRating           27388 non-null  int64
#  19  numVotes                27388 non-null  int64
#  20  cast.1                  26109 non-null  str
#  21  cast.2                  25395 non-null  str
#  22  cast.3                  24508 non-null  str
#  23  cast.4                  23487 non-null  str
#  24  cast.5                  22297 non-null  str
#  25  cast.6                  21095 non-null  str
#  26  cast.7                  20011 non-null  str
#  27  cast.8                  19021 non-null  str
#  28  cast.9                  18015 non-null  str
#  29  cast.10                 17052 non-null  str
# dtypes: int64(9), str(21)
# memory usage: 6.5 MB

# %%
print("Revenue = 0: ", (df["revenue"] == 0).sum())
# Out:
# Revenue = 0:  17231

# %%
# Quitar los que no tienen datos de recaudación
df = df [df ["revenue"] != 0]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10157 entries, 0 to 436232
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      10157 non-null  int64
#  1   title                   10157 non-null  str
#  2   vote_average            10157 non-null  int64
#  3   vote_count              10157 non-null  int64
#  4   status                  10157 non-null  str
#  5   release_date            10123 non-null  str
#  6   revenue                 10157 non-null  int64
#  7   runtime                 10157 non-null  int64
#  8   adult                   10157 non-null  str
#  9   budget                  10157 non-null  int64
#  10  imdb_id                 10157 non-null  str
#  11  original_language       10157 non-null  str
#  12  original_title          10157 non-null  str
#  13  popularity              10157 non-null  int64
#  14  genre                   10157 non-null  str
#  15  production_countries.1  9867 non-null   str
#  16  production_countries.2  2512 non-null   str
#  17  director                10125 non-null  str
#  18  averageRating           10157 non-null  int64
#  19  numVotes                10157 non-null  int64
#  20  cast.1                  10076 non-null  str
#  21  cast.2                  9999 non-null   str
#  22  cast.3                  9943 non-null   str
#  23  cast.4                  9877 non-null   str
#  24  cast.5                  9781 non-null   str
#  25  cast.6                  9645 non-null   str
#  26  cast.7                  9501 non-null   str
#  27  cast.8                  9384 non-null   str
#  28  cast.9                  9217 non-null   str
#  29  cast.10                 9057 non-null   str
# dtypes: int64(9), str(21)
# memory usage: 2.4 MB

# %%
print(df["release_date"].min())
print(df["release_date"].max())
# Out:
# 01/01/1938
# 31/12/2019

# %% [markdown]
# Valoré ampliar el dataset
# Mojo tiene datos de recaudación actualizados. Pero los datasets disponibles son de 3000 películas o similar. Solicité acceso a la API pero no me ha llegado aun el OK.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Voy a ver cómo se distribuyen en el tiempo esas películas
# Me voy a crear una columna año
df['year'] = pd.to_datetime (df['release_date']).dt.year
df['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# C:\Users\NaiaJon\AppData\Local\Temp\ipykernel_11820\2141088463.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['year'] = pd.to_datetime (df['release_date']).dt.year
# <Axes: xlabel='year'>

# %%
df['year'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='year'>

# %%
#Intentando hacer un gráfico con seaborn parece que me daba que había errores en year
df['year'].isnull().sum()
# Out:
# np.int64(34)

# %%
df['year'].max()
# Out:
# np.float64(2024.0)

# %%
df[(df['year'] >= 1980) & (df['year'] <= 2019)].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8351 entries, 0 to 431842
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      8351 non-null   int64
#  1   title                   8351 non-null   str
#  2   vote_average            8351 non-null   int64
#  3   vote_count              8351 non-null   int64
#  4   status                  8351 non-null   str
#  5   release_date            8351 non-null   str
#  6   revenue                 8351 non-null   int64
#  7   runtime                 8351 non-null   int64
#  8   adult                   8351 non-null   str
#  9   budget                  8351 non-null   int64
#  10  imdb_id                 8351 non-null   str
#  11  original_language       8351 non-null   str
#  12  original_title          8351 non-null   str
#  13  popularity              8351 non-null   int64
#  14  genre                   8351 non-null   str
#  15  production_countries.1  8174 non-null   str
#  16  production_countries.2  2233 non-null   str
#  17  director                8333 non-null   str
#  18  averageRating           8351 non-null   int64
#  19  numVotes                8351 non-null   int64
#  20  cast.1                  8301 non-null   str
#  21  cast.2                  8256 non-null   str
#  22  cast.3                  8220 non-null   str
#  23  cast.4                  8173 non-null   str
#  24  cast.5                  8096 non-null   str
#  25  cast.6                  7981 non-null   str
#  26  cast.7                  7869 non-null   str
#  27  cast.8                  7780 non-null   str
#  28  cast.9                  7653 non-null   str
#  29  cast.10                 7523 non-null   str
#  30  year                    8351 non-null   float64
# dtypes: float64(1), int64(9), str(21)
# memory usage: 2.0 MB

# %%
# Antes de 1980 hay pocos datos que creo que alterarían el análisis y después de 2019 parte por la cercanía 
# parte por el COVID (entiendo) también hay pocos datos así que acoto la temporalidad (muy a mi pesar) a 
# 1980 - 2019. Me quedan 8300 valores que no está mal.
df_acotado = df[(df['year'] >= 1980) & (df['year'] <= 2019)]

#parece que ya no hay nulos en year
df_acotado ['year'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Ultimos pasos para preparar el dataframe:
# 1- Valorar si (y cómo incluir los premios)
# 2 - Hay suficiente representación de pelis españolas para hacer tb un análisis propio?
# 3 - Bonus: Premios Vs edad. Sería otro dataframe así que lo dejo por si me queda tiempo

# %%
oscars = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\Oscar_Awards.csv", sep="\t")
print(oscars.shape)
oscars.tail()
# Out:
# (12014, 16)
#        Ceremony  Year    Class  \
# 12009        97  2024  SciTech
# 12010        97  2024  SciTech
# 12011        97  2024  SciTech
# 12012        97  2024  SciTech
# 12013        97  2024  SciTech
#
#                                        CanonicalCategory  \
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12010  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12011  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12012  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12013  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
#
#                                                 Category NomId Film FilmId  \
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12010  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12011  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12012  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12013  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
#
#       Name                                           Nominees NomineeIds  \
# 12009  NaN                        Dustin Brooks, Colin Decker        NaN
# 12010  NaN                          Attila T. Áfra, Timo Aila        NaN
# 12011  NaN                                          Mark Noel        NaN
# 12012  NaN                  Su Tie, Bei Shimen, Zhao Yanchong        NaN
# 12013  NaN  Tabb Firchau, John Ellison, Steve Webb, David ...        NaN
#
#       Winner Detail                                               Note  \
# 12009   True    NaN  Fire for Hire's gel first publicly demonstrate...
# 12010   True    NaN  Open Image Denoise is an open-source library t...
# 12011   True    NaN  The NACMO series of modular motion bases enabl...
# 12012   True    NaN  Utilizing three-axis stabilization through mul...
# 12013   True    NaN  Freefly Systems' introduction of handheld stab...
#
#                                                 Citation MultifilmNomination
# 12009  To DUSTIN BROOKS and COLIN DECKER for the deve...                 NaN
# 12010  To ATTILA T. ÁFRA for the creation of Intel Op...                 NaN
# 12011  To MARK NOEL for adapting and enhancing the sa...                 NaN
# 12012  To SU TIE for the development of the sensor an...                 NaN
# 12013  To TABB FIRCHAU for the conception and develop...                 NaN

# %%
# Habría que contabilizar por filmId pero ya veo que hay NaNs en ese campo
oscars ['FilmId'].isnull().sum()
# Out:
# np.int64(1261)

# %%
#Investigar si son relevantes, si son de pelis antiguas que ya voy a descartar o de categorías como documentales
# etc puedo pasar sin ellos

nulos = oscars[oscars ['FilmId'].isnull()]
nulos.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1261 entries, 22 to 12013
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ceremony             1261 non-null   int64
#  1   Year                 1261 non-null   str
#  2   Class                1261 non-null   str
#  3   CanonicalCategory    1261 non-null   str
#  4   Category             1261 non-null   str
#  5   NomId                729 non-null    str
#  6   Film                 0 non-null      str
#  7   FilmId               0 non-null      str
#  8   Name                 121 non-null    str
#  9   Nominees             1260 non-null   str
#  10  NomineeIds           733 non-null    str
#  11  Winner               1235 non-null   object
#  12  Detail               810 non-null    str
#  13  Note                 371 non-null    str
#  14  Citation             1140 non-null   str
#  15  MultifilmNomination  0 non-null      object
# dtypes: int64(1), object(2), str(13)
# memory usage: 167.5+ KB

# %%
#Año
nulos['Year'].describe()
# Out:
# count     1261
# unique      95
# top       1998
# freq        38
# Name: Year, dtype: object

# %%
nulos['Category'].value_counts()
# Out:
# Category
# SCIENTIFIC AND TECHNICAL AWARD (Technical Achievement Award)         254
# SCIENTIFIC OR TECHNICAL AWARD (Class III)                            180
# SCIENTIFIC AND TECHNICAL AWARD (Scientific and Engineering Award)    170
# HONORARY AWARD                                                       128
# SCIENTIFIC OR TECHNICAL AWARD (Class II)                              91
# SCIENTIFIC OR TECHNICAL AWARD (Technical Achievement Award)           89
# SCIENTIFIC OR TECHNICAL AWARD (Scientific and Engineering Award)      67
# IRVING G. THALBERG MEMORIAL AWARD                                     46
# JEAN HERSHOLT HUMANITARIAN AWARD                                      45
# SPECIAL AWARD                                                         33
# GORDON E. SAWYER AWARD                                                27
# SCIENTIFIC AND TECHNICAL AWARD (Academy Award of Merit)               21
# JOHN A. BONNER MEDAL OF COMMENDATION                                  20
# SCIENTIFIC OR TECHNICAL AWARD (Class I)                               18
# ASSISTANT DIRECTOR                                                    18
# MEDAL OF COMMENDATION                                                 18
# AWARD OF COMMENDATION                                                 12
# SCIENTIFIC OR TECHNICAL AWARD (Academy Award of Merit)                11
# SOUND RECORDING                                                        8
# ENGINEERING EFFECTS                                                    2
# WRITING (Title Writing)                                                2
# SCIENTIFIC AND TECHNICAL AWARD (Special Award)                         1
# Name: count, dtype: int64

# %%
#La mayoría son honoríficos o a categorías técnicas. Podríamos pasar de ellos. Voy a ver cuántos me quedan
# acotando a los años del estudio
# Errores: el año estaba en string y además hay entradas que eran del tipo 1927/1928
nulos ['Year'] = nulos['Year'].str[:4].astype (int)

# %%
nulos [(nulos['Year']>=1980) & (nulos['Year']<=2020)].info() #los premios se dan con un año de retraso
# Out:
# <class 'pandas.DataFrame'>
# Index: 726 entries, 6272 to 11478
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ceremony             726 non-null    int64
#  1   Year                 726 non-null    int64
#  2   Class                726 non-null    str
#  3   CanonicalCategory    726 non-null    str
#  4   Category             726 non-null    str
#  5   NomId                437 non-null    str
#  6   Film                 0 non-null      str
#  7   FilmId               0 non-null      str
#  8   Name                 35 non-null     str
#  9   Nominees             725 non-null    str
#  10  NomineeIds           437 non-null    str
#  11  Winner               726 non-null    object
#  12  Detail               501 non-null    str
#  13  Note                 313 non-null    str
#  14  Citation             691 non-null    str
#  15  MultifilmNomination  0 non-null      object
# dtypes: int64(2), object(2), str(12)
# memory usage: 96.4+ KB

# %%
#Hay 726 nulos en el rango a estudiar

# %%
nulos [(nulos['Year']>=1980) & (nulos['Year']<=2020)]["Category"].value_counts()
# Out:
# Category
# SCIENTIFIC AND TECHNICAL AWARD (Technical Achievement Award)         232
# SCIENTIFIC AND TECHNICAL AWARD (Scientific and Engineering Award)    155
# SCIENTIFIC OR TECHNICAL AWARD (Technical Achievement Award)           75
# HONORARY AWARD                                                        67
# SCIENTIFIC OR TECHNICAL AWARD (Scientific and Engineering Award)      65
# GORDON E. SAWYER AWARD                                                26
# JEAN HERSHOLT HUMANITARIAN AWARD                                      22
# SCIENTIFIC AND TECHNICAL AWARD (Academy Award of Merit)               21
# JOHN A. BONNER MEDAL OF COMMENDATION                                  20
# IRVING G. THALBERG MEMORIAL AWARD                                     13
# AWARD OF COMMENDATION                                                 12
# MEDAL OF COMMENDATION                                                 10
# SCIENTIFIC OR TECHNICAL AWARD (Academy Award of Merit)                 7
# SCIENTIFIC AND TECHNICAL AWARD (Special Award)                         1
# Name: count, dtype: int64

# %% [markdown]
# Son premios técnicos y honoríficos. Por eso no tienen FilmId la mayoría. Los eliminamos

# %%
oscars ['Year'] = oscars ['Year'].str[:4].astype (int)

# %%
#Me quedo con los años
oscars_acotado = oscars [(oscars ['Year'] >= 1980)&(oscars ['Year'] <= 2020)]

# %%
#Quito los premios sin FIlmId
oscars_acotado = oscars_acotado[oscars_acotado['FilmId'].notnull()]

# %%
oscars_acotado.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4578 entries, 6175 to 11476
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ceremony             4578 non-null   int64
#  1   Year                 4578 non-null   int64
#  2   Class                4578 non-null   str
#  3   CanonicalCategory    4578 non-null   str
#  4   Category             4578 non-null   str
#  5   NomId                4578 non-null   str
#  6   Film                 4578 non-null   str
#  7   FilmId               4578 non-null   str
#  8   Name                 4575 non-null   str
#  9   Nominees             4373 non-null   str
#  10  NomineeIds           4373 non-null   str
#  11  Winner               972 non-null    object
#  12  Detail               1015 non-null   str
#  13  Note                 11 non-null     str
#  14  Citation             3 non-null      str
#  15  MultifilmNomination  0 non-null      object
# dtypes: int64(2), object(2), str(12)
# memory usage: 608.0+ KB

# %%
type (oscars_acotado)
# Out:
# pandas.DataFrame

# %%
#Necesito crearme un dataframe con:
# Film Id
# Número nominaciones
# Número de oscars
# en winner está como null los no ganadores: sustituir por False
# Y luego hacer un merge al dataframe de trabajo

oscars_acotado = oscars_acotado [['Year','FilmId','Category','Winner']]

# %%
oscars_acotado.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4578 entries, 6175 to 11476
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      4578 non-null   int64
#  1   FilmId    4578 non-null   str
#  2   Category  4578 non-null   str
#  3   Winner    972 non-null    object
# dtypes: int64(1), object(1), str(2)
# memory usage: 178.8+ KB

# %%
oscars_acotado.fillna(False, inplace=True)
# Out:
#        Year      FilmId                       Category Winner
# 6175   1980   tt0081398        ACTOR IN A LEADING ROLE   True
# 6176   1980   tt0079239        ACTOR IN A LEADING ROLE  False
# 6177   1980   tt0080678        ACTOR IN A LEADING ROLE  False
# 6178   1980   tt0081656        ACTOR IN A LEADING ROLE  False
# 6179   1980   tt0081568        ACTOR IN A LEADING ROLE  False
# ...     ...         ...                            ...    ...
# 11472  2020   tt9784798  WRITING (Original Screenplay)  False
# 11473  2020  tt10633456  WRITING (Original Screenplay)  False
# 11474  2020   tt9620292  WRITING (Original Screenplay)   True
# 11475  2020   tt5363618  WRITING (Original Screenplay)  False
# 11476  2020   tt1070874  WRITING (Original Screenplay)  False
#
# [4578 rows x 4 columns]

# %%
oscars_acotado.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4578 entries, 6175 to 11476
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      4578 non-null   int64
#  1   FilmId    4578 non-null   str
#  2   Category  4578 non-null   str
#  3   Winner    4578 non-null   object
# dtypes: int64(1), object(1), str(2)
# memory usage: 178.8+ KB

# %%
#ASIGNAR! SI no no hace nada!!!
oscars_acotado['Winner'] = oscars_acotado['Winner'].astype(int)

# %%
# Contar los nominados (filas) y premios (Trues)
awards_and_nominees = oscars_acotado.groupby('FilmId')['Winner'].aggregate(['count', 'sum']).rename(columns={'count': 'nominees', 'sum': 'awards'}).reset_index()

# %%
awards_and_nominees.head()
# Out:
#       FilmId  nominees  awards
# 0  tt0035423         1       0
# 1  tt0078868         1       0
# 2  tt0079239         2       0
# 3  tt0079579         1       1
# 4  tt0079596         1       0

# %%
awards_and_nominees ['nominees'].max()
# Out:
# np.int64(14)

# %%
awards_and_nominees.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2206 entries, 0 to 2205
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FilmId    2206 non-null   str
#  1   nominees  2206 non-null   int64
#  2   awards    2206 non-null   int64
# dtypes: int64(2), str(1)
# memory usage: 51.8 KB

# %%
df_acotado.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8351 entries, 0 to 431842
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      8351 non-null   int64
#  1   title                   8351 non-null   str
#  2   vote_average            8351 non-null   int64
#  3   vote_count              8351 non-null   int64
#  4   status                  8351 non-null   str
#  5   release_date            8351 non-null   str
#  6   revenue                 8351 non-null   int64
#  7   runtime                 8351 non-null   int64
#  8   adult                   8351 non-null   str
#  9   budget                  8351 non-null   int64
#  10  imdb_id                 8351 non-null   str
#  11  original_language       8351 non-null   str
#  12  original_title          8351 non-null   str
#  13  popularity              8351 non-null   int64
#  14  genre                   8351 non-null   str
#  15  production_countries.1  8174 non-null   str
#  16  production_countries.2  2233 non-null   str
#  17  director                8333 non-null   str
#  18  averageRating           8351 non-null   int64
#  19  numVotes                8351 non-null   int64
#  20  cast.1                  8301 non-null   str
#  21  cast.2                  8256 non-null   str
#  22  cast.3                  8220 non-null   str
#  23  cast.4                  8173 non-null   str
#  24  cast.5                  8096 non-null   str
#  25  cast.6                  7981 non-null   str
#  26  cast.7                  7869 non-null   str
#  27  cast.8                  7780 non-null   str
#  28  cast.9                  7653 non-null   str
#  29  cast.10                 7523 non-null   str
#  30  year                    8351 non-null   float64
# dtypes: float64(1), int64(9), str(21)
# memory usage: 2.0 MB

# %%
awards_and_nominees.rename (columns={"FilmId": "imdb_id"}, inplace=True)

# %%
#Agregar estas filas al dataset de trabajo. Mantener todo el dataset y que añada los premios/nominaciones
#donde coincida

df_pelisfinal = df_acotado.merge (awards_and_nominees, how='left', on='imdb_id')

# %%
df_pelisfinal.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8351 entries, 0 to 8350
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      8351 non-null   int64
#  1   title                   8351 non-null   str
#  2   vote_average            8351 non-null   int64
#  3   vote_count              8351 non-null   int64
#  4   status                  8351 non-null   str
#  5   release_date            8351 non-null   str
#  6   revenue                 8351 non-null   int64
#  7   runtime                 8351 non-null   int64
#  8   adult                   8351 non-null   str
#  9   budget                  8351 non-null   int64
#  10  imdb_id                 8351 non-null   str
#  11  original_language       8351 non-null   str
#  12  original_title          8351 non-null   str
#  13  popularity              8351 non-null   int64
#  14  genre                   8351 non-null   str
#  15  production_countries.1  8174 non-null   str
#  16  production_countries.2  2233 non-null   str
#  17  director                8333 non-null   str
#  18  averageRating           8351 non-null   int64
#  19  numVotes                8351 non-null   int64
#  20  cast.1                  8301 non-null   str
#  21  cast.2                  8256 non-null   str
#  22  cast.3                  8220 non-null   str
#  23  cast.4                  8173 non-null   str
#  24  cast.5                  8096 non-null   str
#  25  cast.6                  7981 non-null   str
#  26  cast.7                  7869 non-null   str
#  27  cast.8                  7780 non-null   str
#  28  cast.9                  7653 non-null   str
#  29  cast.10                 7523 non-null   str
#  30  year                    8351 non-null   float64
#  31  nominees                1095 non-null   float64
#  32  awards                  1095 non-null   float64
# dtypes: float64(3), int64(9), str(21)
# memory usage: 2.1 MB

# %%
#Por qué sólo 1095?? Qué pasa con el resto?

# %%
awards_and_nominees ['imdb_id'].sample (20)
# Out:
# 321     tt0091763
# 801     tt0114746
# 880     tt0118632
# 1496    tt0874952
# 1787    tt1800241
# 1126    tt0253474
# 805     tt0114898
# 878     tt0118607
# 981     tt0141401
# 850     tt0117381
# 2115    tt6304162
# 758     tt0112431
# 1034    tt0180093
# 605     tt0104007
# 905     tt0119654
# 1620    tt1201607
# 217     tt0087932
# 1953    tt3263904
# 1089    tt0212720
# 1938    tt3044564
# Name: imdb_id, dtype: str

# %%
df_acotado ['imdb_id'].sample (20)
# Out:
# 9787      tt0080437
# 82211     tt1283472
# 1923      tt1064932
# 5751      tt1571249
# 1981      tt1034032
# 2773      tt1971325
# 9923      tt0099611
# 5702      tt3462710
# 29607     tt0357894
# 1578      tt0478304
# 2714      tt0889583
# 1811      tt6306064
# 747       tt0118971
# 239116    tt0489075
# 2935      tt0267804
# 11992     tt0275719
# 753       tt5580036
# 999       tt0435651
# 5159      tt1521197
# 22461     tt0473709
# Name: imdb_id, dtype: str

# %%
no_estan = awards_and_nominees[~awards_and_nominees['imdb_id'].isin(df_acotado['imdb_id'])]
no_estan ['imdb_id'].sample (20)
# Out:
# 1113     tt0243133
# 1100     tt0236447
# 197      tt0087091
# 2110     tt6212516
# 416      tt0095276
# 149      tt0085461
# 401      tt0094819
# 48       tt0081568
# 1569    tt10627584
# 1933     tt2991224
# 1196     tt0309121
# 1531     tt0982919
# 493      tt0098962
# 476      tt0097509
# 1601    tt11512676
# 433      tt0096028
# 1462     tt0775529
# 2130     tt6634646
# 80       tt0082736
# 2148     tt7129636
# Name: imdb_id, dtype: str

# %%
# Parece que les faltaban datos de presupuesto, recaudación o género. 
# Me quedo con las 1095 premiadas
# Reviso que los datos y tipos del dataset están correctos

# %%
df_pelisfinal ['awards'] = df_pelisfinal ['awards'].fillna (0)
df_pelisfinal ['nominees']= df_pelisfinal ['nominees'].fillna (0)

# %%
df_pelisfinal.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8351 entries, 0 to 8350
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      8351 non-null   int64
#  1   title                   8351 non-null   str
#  2   vote_average            8351 non-null   int64
#  3   vote_count              8351 non-null   int64
#  4   status                  8351 non-null   str
#  5   release_date            8351 non-null   str
#  6   revenue                 8351 non-null   int64
#  7   runtime                 8351 non-null   int64
#  8   adult                   8351 non-null   str
#  9   budget                  8351 non-null   int64
#  10  imdb_id                 8351 non-null   str
#  11  original_language       8351 non-null   str
#  12  original_title          8351 non-null   str
#  13  popularity              8351 non-null   int64
#  14  genre                   8351 non-null   str
#  15  production_countries.1  8174 non-null   str
#  16  production_countries.2  2233 non-null   str
#  17  director                8333 non-null   str
#  18  averageRating           8351 non-null   int64
#  19  numVotes                8351 non-null   int64
#  20  cast.1                  8301 non-null   str
#  21  cast.2                  8256 non-null   str
#  22  cast.3                  8220 non-null   str
#  23  cast.4                  8173 non-null   str
#  24  cast.5                  8096 non-null   str
#  25  cast.6                  7981 non-null   str
#  26  cast.7                  7869 non-null   str
#  27  cast.8                  7780 non-null   str
#  28  cast.9                  7653 non-null   str
#  29  cast.10                 7523 non-null   str
#  30  year                    8351 non-null   float64
#  31  nominees                8351 non-null   float64
#  32  awards                  8351 non-null   float64
# dtypes: float64(3), int64(9), str(21)
# memory usage: 2.1 MB

# %%
# Hay muchas columnas con info que no sé si voy a usar. Voy a quedarme con las principales
pelis_categorias_ppales = df_pelisfinal[list(df_pelisfinal.columns[:15]) + ['averageRating'] + list(df_pelisfinal.columns[-3:])]

# %%
pelis_categorias_ppales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8351 entries, 0 to 8350
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8351 non-null   int64
#  1   title              8351 non-null   str
#  2   vote_average       8351 non-null   int64
#  3   vote_count         8351 non-null   int64
#  4   status             8351 non-null   str
#  5   release_date       8351 non-null   str
#  6   revenue            8351 non-null   int64
#  7   runtime            8351 non-null   int64
#  8   adult              8351 non-null   str
#  9   budget             8351 non-null   int64
#  10  imdb_id            8351 non-null   str
#  11  original_language  8351 non-null   str
#  12  original_title     8351 non-null   str
#  13  popularity         8351 non-null   int64
#  14  genre              8351 non-null   str
#  15  averageRating      8351 non-null   int64
#  16  year               8351 non-null   float64
#  17  nominees           8351 non-null   float64
#  18  awards             8351 non-null   float64
# dtypes: float64(3), int64(8), str(8)
# memory usage: 1.2 MB

# %%
pelis_categorias_ppales.sample(5)
# Out:
#           id                            title  vote_average  vote_count  \
# 3220  157845                        The Rover          6279         868
# 3923   10894                              May          6499         544
# 6034   11243             The Care Bears Movie          5426         102
# 5083  157099  Better Living Through Chemistry          5926         244
# 7039   25186                  Janky Promoters          5923          26
#
#         status release_date   revenue  runtime  adult    budget    imdb_id  \
# 3220  Released   04/06/2014   2510007      103  FALSO  12250000  tt2345737
# 3923  Released   02/05/2003    264349       93  FALSO    500000  tt0303361
# 6034  Released   23/03/1985  34000000       76  FALSO   2000000  tt0088885
# 5083  Released   14/03/2014     75143       91  FALSO   5000000  tt1609479
# 7039  Released   16/10/2009      9069       85  FALSO  10000000  tt1210071
#
#      original_language                   original_title  popularity  \
# 3220                en                        The Rover       14501
# 3923                en                              May       10342
# 6034                en             The Care Bears Movie       11208
# 5083                en  Better Living Through Chemistry       11646
# 7039                en                  Janky Promoters        4094
#
#           genre  averageRating    year  nominees  awards
# 3220      Crime             64  2014.0       0.0     0.0
# 3923     Comedy             66  2003.0       0.0     0.0
# 6034  Adventure             56  1985.0       0.0     0.0
# 5083      Drama             62  2014.0       0.0     0.0
# 7039     Comedy             51  2009.0       0.0     0.0

# %%
#Hay tres valores de popularidad. Unificar
pelis_categorias_ppales['vote_average'].describe()
# Out:
# count    8351.000000
# mean     4397.906718
# std      2980.318447
# min         0.000000
# 25%       100.000000
# 50%      5901.000000
# 75%      6685.000000
# max      8702.000000
# Name: vote_average, dtype: float64

# %%
pelis_categorias_ppales ['popularity'].describe()
# Out:
# count      8351.000000
# mean      14937.751766
# std       16107.962556
# min           0.000000
# 25%        4306.000000
# 50%       12146.000000
# 75%       19348.500000
# max      357731.000000
# Name: popularity, dtype: float64

# %%
pelis_categorias_ppales ['averageRating'].describe()
# Out:
# count    8351.000000
# mean       63.065621
# std        11.229303
# min        11.000000
# 25%        57.000000
# 50%        64.000000
# 75%        71.000000
# max       100.000000
# Name: averageRating, dtype: float64

# %%
df_pelisfinal['vote_average'].sample(10)
# Out:
# 8350       0
# 1087    6563
# 903     7837
# 5       7606
# 3007    6248
# 4151    5816
# 5796    6788
# 160     7931
# 7628      59
# 2436    6712
# Name: vote_average, dtype: int64

# %%
# Me quedo sólo con average_rating. Las otras dos o miden otra cosa (parece que popularity mide 
# búsquedas e impactos y no valoraciones). Vote average creo que se ha corrompido en algún punto. Tiene una distribución muy
# rara.

# %%
pelis_categorias_ppales=pelis_categorias_ppales.drop (columns=["popularity", "vote_average"])

# %%
pelis_categorias_ppales=pelis_categorias_ppales.drop (columns=["vote_count"])

# %%
# Como valor comparativo es interesante ver el retorno de inversión: cuanto recaudan en relación a lo que cuestan
# Creo la columna ROI
pelis_categorias_ppales ['ROI'] = pelis_categorias_ppales ['revenue']/pelis_categorias_ppales['budget']

# %%
pelis_categorias_ppales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8351 entries, 0 to 8350
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8351 non-null   int64
#  1   title              8351 non-null   str
#  2   status             8351 non-null   str
#  3   release_date       8351 non-null   str
#  4   revenue            8351 non-null   int64
#  5   runtime            8351 non-null   int64
#  6   adult              8351 non-null   str
#  7   budget             8351 non-null   int64
#  8   imdb_id            8351 non-null   str
#  9   original_language  8351 non-null   str
#  10  original_title     8351 non-null   str
#  11  genre              8351 non-null   str
#  12  averageRating      8351 non-null   int64
#  13  year               8351 non-null   float64
#  14  nominees           8351 non-null   float64
#  15  awards             8351 non-null   float64
#  16  ROI                8351 non-null   float64
# dtypes: float64(4), int64(5), str(8)
# memory usage: 1.1 MB

# %%
# Boxplots de las categorías numéricas para ver si hay cosas raras. Las pinto en plots distintos porque
# hay 

import matplotlib.pyplot as plt
cols = ["revenue", "runtime","budget","averageRating","ROI"]
fig, axes = plt.subplots(1, len(cols), figsize=(20, 5))
for i, col in enumerate(cols):
    sns.boxplot(data=pelis_categorias_ppales[col], ax=axes[i])
    axes[i].set_title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Hay cosas demasiado raras en revenue y budget. Parece que hay muchos valores muy bajos. Hay que determinar dónde limitamos para distinguir qué es un error de una peli de muy bajo presupuesto

# %%
print((pelis_categorias_ppales['budget'] < 1000).sum())
print((pelis_categorias_ppales['revenue'] < 1000).sum())
# Out:
# 166
# 172

# %%
# Cuantas hay por debajo de 100000 dólares
print((pelis_categorias_ppales['budget'] < 100000).sum())
# Out:
# 510

# %%
pelis_categorias_ppales[pelis_categorias_ppales['budget'] < 100000]['budget'].describe()
# Out:
# count      510.000000
# mean     16670.243137
# std      23115.135108
# min          1.000000
# 25%        263.250000
# 50%       9150.000000
# 75%      20142.500000
# max      96000.000000
# Name: budget, dtype: float64

# %% [markdown]
# La mediana son 9150. Voy a quitar las de presupuesto menor de 10.000

# %%
pelis_categorias_ppales = pelis_categorias_ppales [pelis_categorias_ppales['budget']>=10000]

# %%
# Vamos a ver lo mismo con revenue
pelis_categorias_ppales[pelis_categorias_ppales['revenue'] < 10000]['revenue'].describe()
# Out:
# count     109.000000
# mean     3496.899083
# std      2974.010087
# min         1.000000
# 25%       881.000000
# 50%      2970.000000
# 75%      5728.000000
# max      9617.000000
# Name: revenue, dtype: float64

# %%
pelis_categorias_ppales[pelis_categorias_ppales['revenue'] < 10000][['imdb_id','revenue']]
# Out:
#         imdb_id  revenue
# 3935  tt3177316     9318
# 3969  tt1519461     7556
# 4041  tt0154421     7235
# 4367  tt0120860     6374
# 4431  tt2383068     9221
# ...         ...      ...
# 8212  tt4232188     5000
# 8214  tt7616710       17
# 8229  tt5761968     5152
# 8284  tt6449580     2000
# 8294  tt2460506     3330
#
# [109 rows x 2 columns]

# %% [markdown]
# He ido a comprobar a Box Office Mojo. Por ejemplo los 9318 son correctos pero sólo está contando la recaudación doméstica.
# https://www.boxofficemojo.com/title/tt3177316/?ref_=bo_se_r_1
# He comprobado otro par alrededor de 5000 y los datos son correctos

# %%
pelis_categorias_ppales[pelis_categorias_ppales['revenue'] < 4000][['imdb_id','revenue']]
# Out:
#         imdb_id  revenue
# 4904  tt0953318       27
# 4969  tt0400426      743
# 4979  tt7869070     3153
# 5340  tt5096536     3176
# 5390  tt1867093     2521
# ...         ...      ...
# 8166  tt1578802      500
# 8190  tt8286772     2263
# 8214  tt7616710       17
# 8284  tt6449580     2000
# 8294  tt2460506     3330
#
# [64 rows x 2 columns]

# %% [markdown]
# Lo mismo. Hay algunas que o no tienen datos o son erróneos y otras que han cogido sólo la recaudación doméstica. Voy a quitar todas las de menos de 5000 dólares de recaudación

# %%
pelis_categorias_ppales = pelis_categorias_ppales [pelis_categorias_ppales['revenue']>=5000]

# %%
import matplotlib.pyplot as plt
cols = ["revenue", "runtime","budget","averageRating","ROI"]
fig, axes = plt.subplots(1, len(cols), figsize=(20, 5))
for i, col in enumerate(cols):
    sns.boxplot(data=pelis_categorias_ppales[col], ax=axes[i])
    axes[i].set_title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Ahora que tengo el dataset limpio para trabajar me lo voy a guardar en un csv para no tener que ejecutar todo lo anterior cada vez que empiezo a trabajar

# %%
pelis_categorias_ppales.to_csv ('data/pelis_ppal.csv', sep=';', index=False)

# %%
#Para ejecutar desde aquí
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pelis = pd.read_csv ('data/pelis_ppal.csv', sep=';')

# %%
pelis ['original_language'].value_counts()
# Out:
# original_language
# en    6079
# hi     296
# fr     226
# ru     194
# es     156
#       ...
# mn       1
# si       1
# km       1
# az       1
# dv       1
# Name: count, Length: 61, dtype: int64

# %% [markdown]
# ### ANÁLISIS VARIABLES

# %%
# En general, qué correlaciones entre datos hay?
sns.heatmap(pelis.select_dtypes(include='number').corr().round(2),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7), #aquí ha fijado los parámetros de la escala de color para que sea apropiado para el heatmap
            linewidths=.1,
            annot=True);

# %% [markdown]
# budget-revenue (0.76): la correlación más clara: más presupuesto = más recaudación.
# nominees-awards (0.77): más nominaciones = más premios (no aporta mucho, está claro que es imposible que te den premios si no te nominan)
# averageRating-nominees (0.31): las películas mejor valoradas tienden a tener más nominaciones, aunque la correlación es moderada.
# nominees-revenue (0.28) : las peliculas nominadas tienden a recaudar más. Es muy moderada
# averageRating-runtime (0.28) y runtime-nominees (0.23): correlaciones débiles pero curiosas, las películas más largas tienden a nominarse y valorarse más.

# %%
# -	¿Las películas con mayor presupuesto recaudan más?
# Como medida para estos análisis voy a tomar si la película ha sido nominada o no independientemente
# de si ha ganado o de cuantas nominaciones ha recibido. Más adelante analizaré el comportamiento de
# las grandes triunfadoras

pelis['nominadas'] = pelis['nominees'] > 0
sns.scatterplot(data=pelis, x='budget', y='revenue', hue='nominadas')
# Out:
# <Axes: xlabel='budget', ylabel='revenue'>

# %%
# -	¿Las de mayor presupuesto tienen más nominaciones?
#Añado una escala logarítmica para ver mejor los datos. Al haber tantos outliers de presupuesto/recaudación alta los puntos se concentran en la
# parte inferior izda y no se aprecia bien
sns.scatterplot(data=pelis, x='budget', y='revenue', hue='nominadas')
plt.xscale('log')
plt.yscale('log')

# %%
pelis['budget_M'] = pelis['budget'] / 1e6
pelis['revenue_M'] = pelis['revenue'] / 1e6

# %%
fig, ax = plt.subplots(figsize=(10, 6), facecolor='#00002e')
ax.set_facecolor('#00002e')

sns.scatterplot(data=pelis, x='budget_M', y='revenue_M', hue='nominadas',
                palette={False: '#4A90D9', True: '#F5A623'},
                alpha=0.7, ax=ax)

# Colores del texto y ejes en blanco para que se vean
ax.tick_params(colors='white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')
plt.setp(ax.spines.values(), color='white')
legend = ax.get_legend()
legend.get_frame().set_facecolor('#00002e')
legend.get_title().set_color('white')
for text in legend.get_texts():
    text.set_color('white')
plt.xlabel('Presupuesto (log)')
plt.ylabel('Recaudación (log)')
#La escala logarítmica porque si no está aplanado
plt.xscale('log')
plt.yscale('log')


#Para que siga manteniendo la escala logarítmica en el eje pero las etiquetas muestren valores 
# comprensibles en millones de euros
from matplotlib.ticker import FuncFormatter
def formato_millones(x, _):
    if x >= 1000:
        return f'{x:.0f}M'
    elif x >= 1:
        return f'{x:.0f}M'
    else:
        return f'{x:.1f}M'
formatter = FuncFormatter(formato_millones)
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)

# %%
import plotly.express as px

fig = px.scatter(pelis, 
                 x='budget_M', 
                 y='revenue_M',
                 color='nominadas',
                 hover_name='title',
                 hover_data={'budget_M': True, 'revenue_M': True, 'genre': True},
                 color_discrete_map={False: '#4A90D9', True: '#F5A623'},
                 title='Valoracion vs Recaudacion',
                 labels={'budget_M': 'Presupuesto', 'revenue_M': 'Recaudacion (mill $)', 'nominadas': 'Nominada'})

fig.update_xaxes(type='log')
fig.update_yaxes(type='log')
fig.update_layout(
    plot_bgcolor='#00002e',
    paper_bgcolor='#00002e',
    font=dict(color='white'),
    xaxis=dict(gridcolor='#334155'),
    yaxis=dict(gridcolor='#334155'),
    legend=dict(bgcolor='#00002e')
)

fig.show()

# %%
#Parece que sí hay una correlación entre presupuesto y recaudación. 
# Se ve también que las nominaciones se concentran arriba a la derecha, es decir a tener mayor presupuesto y recaudación que las no-nominadas.
# Hay bastantes no nominadas con presupuesto alto, es decir, tener mucho presupuesto no garantiza una nominación.

# %%
#Curiosidad. Cual es la nominada con presupuesto altísimo y recaudación meec
pelis[
    (pelis['budget'] > 100000) & 
    (pelis['revenue'] < 1000000) & 
    (pelis['nominadas']== True)
][['title', 'revenue', 'budget']].sort_values ('budget', ascending=False)
# Out:
#                       title  revenue     budget
# 558            The Irishman   968853  159000000
# 5741     One from the Heart   636796   26000000
# 5942            The Tempest   346594   20000000
# 4960                   W.E.   868439   15000000
# 7415     Gaby: A True Story   125400    5000000
# 5945             Waste Land   187716    1500000
# 3720     The Act of Killing   722714    1000000
# 5338  Taxi to the Dark Side   274661    1000000
# 4359                Tin Toy   123967     300000
# 1857               Dogtooth   110197     275576
# 3922     Children of Heaven   925402     180000

# %%
pelis['nominadas'] = pelis['nominees'] > 0
sns.scatterplot(data=pelis, x='budget', y='ROI', hue='nominadas')
plt.yscale ('log')

# %% [markdown]
# Presupuestos más altos no garantizan una mayor rentabilidad proporcional. Los puntos más altos en el eje y están en los presupuestos más bajos.
# Las películas nominadas no son necesariamente las más rentables aunque se encuentran en su mayoría en la zona de seguridad.

# %%
import plotly.express as px

fig = px.scatter(pelis, 
                 x='budget_M', 
                 y='ROI',
                 color='nominadas',
                 hover_name='title',
                 hover_data={'budget_M': True, 'revenue_M': True, 'genre': True},
                 color_discrete_map={False: '#4A90D9', True: '#F5A623'},
                 title='Valoracion vs Recaudacion',
                 labels={'budget_M': 'Presupuesto', 'ROI': 'ROI', 'nominadas': 'Nominada'})

fig.update_yaxes(type='log')
fig.update_layout(
    plot_bgcolor='#00002e',
    paper_bgcolor='#00002e',
    font=dict(color='white'),
    xaxis=dict(gridcolor='#334155'),
    yaxis=dict(gridcolor='#334155'),
    legend=dict(bgcolor='#00002e')
)
fig.show()

# %%
sns.scatterplot(data=pelis, x='budget', y='revenue', hue='averageRating')
plt.xscale('log')
plt.yscale('log')

# %%
plt.hexbin(pelis['budget'], pelis['revenue'], C=pelis['averageRating'], 
           xscale='log', yscale='log', gridsize=30, cmap='YlOrRd')
plt.colorbar(label='averageRating')

# %%
pelis['rating_categoria'] = pd.cut(pelis['averageRating'], 
                                    bins=[0, 50, 65, 75, 100], 
                                    labels=['Baja', 'Media', 'Alta', 'Muy alta'])

sns.boxplot(data=pelis, x='rating_categoria', y='revenue')
plt.yscale('log')

# %%
sns.scatterplot(data=pelis, x='budget', y='revenue', hue='rating_categoria', palette={'Baja': 'lightblue', 'Media': 'steelblue', 'Alta': 'darkblue', 'Muy alta': 'navy'})
plt.xscale('log')
plt.yscale('log')

# %%
# -	¿Coinciden premios y público?
sns.scatterplot (data=pelis, x='averageRating', y='revenue', hue='nominadas')
plt.yscale('log')

# %%
import plotly.express as px

fig = px.scatter(pelis, 
                 x='averageRating', 
                 y='revenue_M',
                 color='nominadas',
                 hover_name='title',
                 hover_data={'averageRating': True, 'revenue_M': True, 'genre': True},
                 color_discrete_map={False: '#4A90D9', True: '#F5A623'},
                 title='Valoracion vs Recaudacion',
                 labels={'averageRating': 'Valoracion media', 'revenue_M': 'Recaudacion (mill $)', 'nominadas': 'Nominada'})

fig.update_yaxes(type='log')

fig.update_layout(
    plot_bgcolor='#00002e',
    paper_bgcolor='#00002e',
    font=dict(color='white'),
    xaxis=dict(gridcolor='#334155'),
    yaxis=dict(gridcolor='#334155'),
    legend=dict(bgcolor='#00002e')
)

fig.show()

# %%
#Para ponerlo en la presentación:
fig, ax = plt.subplots(figsize=(10, 6), facecolor='#00002e')
ax.set_facecolor('#00002e')

sns.scatterplot(data=pelis, x='averageRating', y='revenue_M', hue='nominadas',
                palette={False: '#4A90D9', True: '#F5A623'},
                alpha=0.7, ax=ax)

plt.yscale('log')

ax.tick_params(colors='white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')
ax.title.set_color('white')
plt.setp(ax.spines.values(), color='#334155')

legend = ax.get_legend()
legend.get_frame().set_facecolor('#00002e')
legend.get_title().set_color('white')
for text in legend.get_texts():
    text.set_color('white')

from matplotlib.ticker import FuncFormatter
def formatter(x, _):
    if x >= 1000:
        return f'{x/1000:.0f}B'
    elif x >= 1:
        return f'{x:.0f}M'
    else:
        return f'{x*1000:.0f}K'

ax.yaxis.set_major_formatter(FuncFormatter(formatter))
ax.set_xlabel('Valoración', color='white')
ax.set_ylabel('Recaudación (log)', color='white')


plt.tight_layout()
plt.show()

# %%
pelis.groupby('nominadas')['averageRating'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%   max
# nominadas
# False      6930.0  61.496248  10.696676  11.0  56.0  63.0  69.0  95.0
# True       1094.0  73.173675   6.616608  37.0  69.0  74.0  78.0  93.0

# %%
#Un p-value podría ser relevante? Revisar
from scipy import stats

nominadas = pelis[pelis['nominadas'] == True]['averageRating']
no_nominadas = pelis[pelis['nominadas'] == False]['averageRating']

stats.ttest_ind(nominadas, no_nominadas)
# Out:
# TtestResult(statistic=np.float64(35.063740837187154), pvalue=np.float64(9.883025004943831e-251), df=np.float64(8022.0))

# %%
sns.countplot(data=pelis, y='genre', hue= 'nominadas', order=pelis['genre'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='genre'>

# %%
#Mirar aquí colores que contrasten bien pero no queden horribles
# # Azul suave para total, dorado para nominadas
# color_total = "#B0C4DE"      # azul acero claro
# color_nominadas = "#C9A84C"  # dorado

# # O una combinación más sobria
# color_total = "#D3D3D3"      # gris claro
# color_nominadas = "#4A7FB5"  # azul medio
sns.countplot(data=pelis, y='genre', order=pelis['genre'].value_counts().index, color="#C7C4C4")
sns.countplot(data=pelis[pelis['nominadas'] == True], y='genre', order=pelis['genre'].value_counts().index, color="#4A7FB5", alpha=0.6)
plt.show()

# %% [markdown]
# Next: añadir, porcentajes en texto, visualizar mejor si hay algun género más/menos nominado de media

# %%
nominaciones_genero = pelis.groupby ('genre').agg ({'nominadas': ('count','mean')})

# %%
nominaciones_genero
# Out:
#                 nominadas
#                     count      mean
# genre
# Action               1220  0.082787
# Adventure             469  0.223881
# Animation             239  0.234310
# Comedy               1781  0.079730
# Crime                 354  0.146893
# Documentary           104  0.163462
# Drama                1881  0.227007
# Family                169  0.147929
# Fantasy               191  0.172775
# History                51  0.254902
# Horror                518  0.015444
# Music                  77  0.142857
# Mystery                84  0.083333
# Romance               247  0.113360
# Science Fiction       180  0.144444
# TV Movie                1  0.000000
# Thriller              358  0.061453
# War                    72  0.180556
# Western                28  0.285714

# %%
#TV Movie es cero relevante como categoría
nominaciones_genero = nominaciones_genero.drop ('TV Movie', axis = 0 )

# %%
nominaciones_genero.columns = ['total','media']
nominaciones_genero ['media'] = (nominaciones_genero ['media']*100).round(1)

# %%
nominaciones_genero_orden= nominaciones_genero.sort_values('media', ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(data=nominaciones_genero_orden, y=nominaciones_genero_orden.index, x='media', color="#378ADD")

media_general = pelis['nominadas'].mean() * 100
plt.axvline(media_general, color='red', linestyle='--', label=f'Media: {media_general:.1f}%')
plt.legend()
plt.xlabel('% nominadas')
plt.title('Porcentaje de películas nominadas por género')
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), facecolor='#00002e')

for ax in axes:
    ax.set_facecolor('#00002e')
    ax.tick_params(colors='white')
    ax.xaxis.label.set_color('white')
    ax.yaxis.label.set_color('white')
    ax.title.set_color('white')
    plt.setp(ax.spines.values(), color='#334155')

# Gráfico 1: countplot con hue
orden = pelis[pelis['genre'] != 'TV Movie']['genre'].value_counts().index
sns.countplot(data=pelis[pelis['genre'] != 'TV Movie'], y='genre', hue='nominadas', order=orden,
              palette={False: '#4A90D9', True: '#F5A623'}, ax=axes[0])
axes[0].set_title('Películas no nominadas vs nominadas por género', color='white')
axes[0].set_xlabel('Número de películas', color='white')
axes[0].set_ylabel('Género', color='white')
legend = axes[0].get_legend()
legend.get_frame().set_facecolor('#00002e')
legend.get_title().set_color('white')
for text in legend.get_texts():
    text.set_color('white')

# Gráfico 2: barplot porcentaje nominadas
nominaciones_genero_orden = nominaciones_genero.sort_values('media', ascending=False)
sns.barplot(data=nominaciones_genero_orden, y=nominaciones_genero_orden.index,
            x='media', color='#4A90D9', ax=axes[1])
media_general = pelis['nominadas'].mean() * 100
axes[1].axvline(media_general, color='#FF4B4B', linestyle='--', linewidth=2.5,
                label=f'Media: {media_general:.1f}%')
axes[1].legend(labelcolor='white', facecolor='#00002e')
axes[1].set_xlabel('% nominadas', color='white')
axes[1].set_ylabel('Género', color='white')
axes[1].set_title('Porcentaje de películas nominadas por género', color='white')

plt.tight_layout()
plt.show()

# %% [markdown]
# Horror es el género más infra-nominado con solo un 1.5% a pesar de que hay muchas peliculas del género
# Wstern y History son los más sobre-nominados con un 25.5% aunque el número de películas es claramente más bajo.
# Drama y Animation también tienen tasas altas (~23%) - Nos gusta un drama: tanto para hacer la peli como para nominarla
# Action y Comedy a pesar de ser casi los géneros con más películas (solo por detrás de drama) tienen tasas bajas (~8%)

# %%
pelis ['count'] = order=pelis['genre'].value_counts()

# %% [markdown]
# ROI por género: ¿hay algún genero más rentable? ¿los Oscars tienen algo que ver con eso?

# %%
roi_genero = pelis.groupby('genre') ['ROI'].mean().round(1).sort_values (ascending=False)

# %%
roi_genero = roi_genero.drop ('TV Movie', axis=0)

# %%
roi_genero.reset_index()
# Out:
#               genre   ROI
# 0            Horror  16.6
# 1       Documentary   9.6
# 2             Music   5.3
# 3           Mystery   4.9
# 4           Romance   4.6
# 5             Drama   4.2
# 6            Comedy   4.2
# 7           Fantasy   3.7
# 8          Thriller   3.6
# 9               War   3.2
# 10  Science Fiction   3.2
# 11        Animation   3.1
# 12           Action   3.1
# 13        Adventure   3.1
# 14           Family   2.8
# 15            Crime   2.7
# 16          History   1.9
# 17          Western   1.6

# %%
roi_genero = pelis.groupby('genre') ['revenue'].mean().round(1).sort_values (ascending=False)

# %%
roi_genero
# Out:
# genre
# Adventure          195667527.4
# Animation          177426456.3
# Family             139638936.7
# Fantasy            138090401.5
# Science Fiction    128101569.8
# Action             115013030.9
# War                 69236224.5
# Mystery             58927946.9
# Thriller            51079557.2
# Comedy              49557704.4
# Western             49194570.4
# Music               47944754.0
# Crime               45468212.2
# Horror              44091463.0
# History             42411041.0
# TV Movie            42000000.0
# Romance             41856588.9
# Drama               38760495.7
# Documentary         11915174.6
# Name: revenue, dtype: float64

# %%
roi_genero.info()
# Out:
# <class 'pandas.Series'>
# Index: 19 entries, Adventure to Documentary
# Series name: revenue
# Non-Null Count  Dtype
# --------------  -----
# 19 non-null     float64
# dtypes: float64(1)
# memory usage: 860.0+ bytes

# %%
sns.barplot(data=pelis, y='genre', x='ROI', color="#4A7FB5")
plt.axvline(pelis['ROI'].mean(), color='red', linestyle='--', label='Media general')
plt.title('Rentabilidad media por género')
plt.xlabel('ROI medio')
plt.ylabel('género')
# Out:
# Text(0, 0.5, 'género')

# %% [markdown]
# Hay cosas interesantes! Justo en contrapartida al tema de nominaciones aquí resulta que de media las películas de terror son por género las más rentables.
# Pero es cierto que la incertidumbre tanto en Terror como en Documental que son las que presentan datos más llamativos es mayor (intervalos muy amplios). En el caso del Documental se ve claro que es por un número bajo de datos. En Horror hay suficientes datos en los que hay mucha dispersión (hay varias películas con rentabilidades altísimas)

# %%
genero_rentabilidad = pelis.groupby('genre').aggregate ({'ROI': ('mean', 'median'),
                                                'budget':'mean'})
genero_rentabilidad.columns = ['Media ROI','Mediana ROI', 'Media presupuesto']

# %%
genero_rentabilidad ['Media ROI'] = genero_rentabilidad ['Media ROI'].round(1)
genero_rentabilidad ['Media presupuesto'] = genero_rentabilidad ['Media presupuesto']/1000000

# %%
genero_rentabilidad.rename ({'Media presupuesto' : 'Media presupuesto (mill $)'}, inplace=True)

# %%
genero_rentabilidad = genero_rentabilidad.drop('TV Movie', axis=0)
genero_rentabilidad.sort_values (by="Media ROI",ascending=False)
# Out:
#                  Media ROI  Mediana ROI  Media presupuesto
# genre
# Horror                16.6     2.506978          12.109591
# Documentary            9.6     1.807859           2.725240
# Music                  5.3     2.933333          13.963933
# Mystery                4.9     1.252990          22.282465
# Romance                4.6     1.946844          14.610851
# Comedy                 4.2     1.904883          18.127339
# Drama                  4.2     1.288132          16.345767
# Fantasy                3.7     1.954816          47.693850
# Thriller               3.6     1.419102          22.378052
# Science Fiction        3.2     1.554429          49.739450
# War                    3.2     1.198333          27.882858
# Action                 3.1     1.696768          41.015029
# Adventure              3.1     1.865180          59.933449
# Animation              3.1     1.955107          50.311432
# Family                 2.8     2.062735          45.458000
# Crime                  2.7     1.453621          21.106978
# History                1.9     0.740741          21.564511
# Western                1.6     0.602372          28.128571

# %% [markdown]
# Géneros de alto presupuesto y ROI moderado (Action, Adventure, Animation, Science Fiction): necesitan mucha inversión para competir, el margen es menor aunque recaudan mucho en términos absolutos.
# Géneros de bajo presupuesto y alto ROI (Horror, Documentary): riesgo financiero menor y aparentemente más fiables en cuanto a rentabilidad
# Géneros equilibrados (Comedy, Drama): presupuesto medio y ROI decente, puede entenderse por qué son el grueso de la industria.

# %%
# Entender cuánto de relevantes son estos datos. Es extensible al género o hay unas cuantas películas 
# que han dado un bombazo y por eso los datos salen así? 

sns.boxplot (data=pelis, y='ROI', x='genre')
plt.xticks (rotation=90);

# %% [markdown]
# Hay unos outliers claros en algunas categorías. CUales son?

# %%
pelis[pelis['genre'] == 'Horror'].sort_values('revenue', ascending=False)[['title', 'revenue','year', 'ROI']].head(5)
# Out:
#                title    revenue    year        ROI
# 59                It  701800000  2017.0  17.545000
# 370   It Chapter Two  473122525  2019.0   5.988893
# 577          The Nun  365582797  2018.0  16.617400
# 151    A Quiet Place  341000000  2018.0  20.058824
# 389  The Conjuring 2  321834351  2016.0   8.045859

# %%
pelis[pelis['genre'] == 'Drama'].sort_values('revenue', ascending=False)[['title', 'revenue','year']].head(5)
# Out:
#                          title     revenue    year
# 17                     Titanic  2264162353  1997.0
# 2              The Dark Knight  1004558444  2008.0
# 52                 The Martian   630600000  2015.0
# 946  The Passion of the Christ   611899420  2004.0
# 112                I Am Legend   585410052  2007.0

# %%
pelis[pelis['genre'] == 'Comedy'].sort_values('revenue', ascending=False)[['title', 'revenue','year']].head(5)
# Out:
#                      title    revenue    year
# 480    Shrek Forever After  752600867  2010.0
# 10            Forrest Gump  677387716  1994.0
# 585             Mamma Mia!  609841637  2008.0
# 276   The Hangover Part II  586764305  2011.0
# 4543           The Mermaid  553810228  2016.0

# %%
pelis[pelis['genre'] == 'Action'].sort_values('revenue', ascending=False)[['title', 'revenue','year']].head(5)
# Out:
#                        title     revenue    year
# 3                     Avatar  2923706026  2009.0
# 44            Jurassic World  1671537444  2015.0
# 262                Furious 7  1515341399  2015.0
# 23   Avengers: Age of Ultron  1405403694  2015.0
# 27             Black Panther  1349926083  2018.0

# %%
pelis[pelis['genre'] == 'Romance'].sort_values('revenue', ascending=False)[['title', 'revenue','year']].head(5)
# Out:
#                             title    revenue    year
# 494                    Cinderella  543514353  2015.0
# 305          Beauty and the Beast  424967620  1991.0
# 822  There's Something About Mary  369884651  1998.0
# 661                  Notting Hill  363889678  1999.0
# 396                       Top Gun  356830601  1986.0

# %%
pelis[pelis['genre'] == 'Documentary'].sort_values('revenue', ascending=False)[['title', 'revenue','year']].head(5)
# Out:
#                                                   title    revenue    year
# 2516                                    Fahrenheit 9/11  222446882  2004.0
# 2930                              March of the Penguins  127392693  2005.0
# 4656                                              Earth  109000000  2007.0
# 6252  Hannah Montana & Miley Cyrus: Best of Both Wor...   70642966  2008.0
# 2992                          One Direction: This Is Us   68500000  2013.0

# %%
#He aplicado log porque salía aplanadísimo.
sns.boxplot (data=pelis, y='ROI', x='genre')
plt.xticks (rotation=90)
plt.yscale ('log');

# %% [markdown]
# Ojo. Aplanando los outliers, las diferencias entre géneros ya no parecen tan grandes. Las medias están muy influenciadas por ejemplos concretos

# %%
sns.barplot(data=genero_rentabilidad, y='genre', x='Mediana ROI', order=genero_rentabilidad.sort_values('Mediana ROI',ascending=False).index, color="#4A7FB5")
plt.axvline(pelis['ROI'].median(), color='red', linestyle='--', label='Media general')
plt.title('Rentabilidad por género -mediana-')
plt.xlabel('ROI medio')
# Out:
# Text(0.5, 0, 'ROI medio')

# %%
#Por ligarlo un poco con el tema de nominaciones vamos a ver si hay algo interesante  comparando ROI de nominadas
#  vs no nominadas
sns.barplot(data=pelis, y='genre', x='ROI', hue='nominadas')
# Out:
# <Axes: xlabel='ROI', ylabel='genre'>

# %% [markdown]
# El patrón general:
# En la mayoría de géneros las nominadas tienen ROI similar o ligeramente superior a las no nominadas, pero hay excepciones claras como Documentary y Mystery donde las nominaciones marca una diferencia enorme.
#
# Las nominaciones a los Oscars no parece garantizan rentabilidad en la mayoría de géneros, con la excepción de Documentary y Mystery.
# Pero al ser categorías con muy pocas películas, es probable que haya una o dos pelis excepcionales que estén alterando la visión
#
# En Terror se da el caso contrario. También la incertidumbre es muy alta.

# %%
# Pelis con ROI más alto de terror y que no estén nominadas
terror = pelis [(pelis['genre'] == 'Horror') & (pelis['nominadas']==False)]
terror [['title', 'ROI']].sort_values ('ROI', ascending = False).head(15)
# Out:
#                           title          ROI
# 857     The Blair Witch Project  4143.984983
# 797         Paranormal Activity   899.329302
# 3198                The Gallows   429.644100
# 1485            Friday the 13th   108.644729
# 3728             The Quiet Ones    89.174335
# 351                         Saw    86.593058
# 1082              The Evil Dead    84.606763
# 540                   Insidious    66.580591
# 1228                 Unfriended    62.882090
# 1647      Paranormal Activity 2    59.170677
# 815   A Nightmare on Elm Street    51.818182
# 1793      Paranormal Activity 3    41.407969
# 623                   Annabelle    39.545794
# 3084          The Last Exorcism    38.573626
# 2310          Chernobyl Diaries    38.390020

# %% [markdown]
# Hay varias películas con retornos altísimos.

# %%
#Qué peliculas están nominadas en las categorías Documentary y Mystery y cual es su ROI
doc_mystery = pelis [((pelis['genre'] == 'Mystery' )| (pelis['genre'] == 'Documentary')) & (pelis['nominadas']==True)]

# %%
doc_mystery [['title','genre','ROI','nominees']].sort_values ('ROI', ascending=False).head(15)
# Out:
#                                               title        genre         ROI  \
# 2254                                  Super Size Me  Documentary  439.616585
# 87                                          Get Out      Mystery   56.757326
# 3344                          An Inconvenient Truth  Documentary   46.243000
# 226                                 The Sixth Sense      Mystery   16.820157
# 2930                          March of the Penguins  Documentary   15.924087
# 4905                                    Hoop Dreams  Documentary   11.186587
# 5349  Born Into Brothels: Calcutta's Red Light Kids  Documentary   10.083431
# 2385                          Bowling for Columbine  Documentary    8.891118
# 4261                            I Am Not Your Negro  Documentary    7.123919
# 67                                        Gone Girl      Mystery    6.054596
# 5210                           20 Feet from Stardom  Documentary    5.892466
# 6170                                     Murderball  Documentary    5.834037
# 136                                         Memento      Mystery    4.413677
# 3249                                     Inside Job  Documentary    3.935761
# 5216                                           Pina  Documentary    3.386987
#
#       nominees
# 2254       1.0
# 87         4.0
# 3344       2.0
# 226        6.0
# 2930       1.0
# 4905       1.0
# 5349       1.0
# 2385       1.0
# 4261       1.0
# 67         1.0
# 5210       1.0
# 6170       1.0
# 136        2.0
# 3249       1.0
# 5216       1.0

# %%
# Merece la pena hacer un análisis de los títulos que lo petaron? Hay suficientes?
pelis[pelis['awards'] >= 3][['title', 'awards', 'nominees']].sort_values('awards', ascending=False)
# Out:
#                                               title  awards  nominees
# 20    The Lord of the Rings: The Return of the King    11.0      11.0
# 17                                          Titanic    11.0      14.0
# 2279                               The Last Emperor     9.0       9.0
# 1868                            The English Patient     9.0      12.0
# 993                                         Amadeus     8.0      11.0
# ...                                             ...     ...       ...
# 3607                             A Room with a View     3.0       8.0
# 3629                             The Killing Fields     3.0       7.0
# 4160                                    Howards End     3.0       9.0
# 4329                                 On Golden Pond     3.0      10.0
# 4817                                           Reds     3.0      12.0
#
# [90 rows x 3 columns]

# %%
# Merece la pena hacer un análisis de los títulos que lo petaron? Hay suficientes?
pelis[pelis['awards'] >= 5][['title', 'awards', 'nominees']].sort_values('awards', ascending=False)
# Out:
#                                               title  awards  nominees
# 17                                          Titanic    11.0      14.0
# 20    The Lord of the Rings: The Return of the King    11.0      11.0
# 1868                            The English Patient     9.0      12.0
# 2279                               The Last Emperor     9.0       9.0
# 266                             Slumdog Millionaire     8.0      10.0
# 993                                         Amadeus     8.0      11.0
# 1741                                         Gandhi     8.0      11.0
# 116                                Schindler's List     7.0      12.0
# 994                              Dances with Wolves     7.0      12.0
# 1372                            Shakespeare in Love     7.0      13.0
# 120                                         Gravity     7.0      10.0
# 2590                                  Out of Africa     7.0      11.0
# 719                                 The Hurt Locker     6.0       9.0
# 10                                     Forrest Gump     6.0      13.0
# 1584                                        Chicago     6.0      13.0
# 97                                       La La Land     6.0      14.0
# 29                               Mad Max: Fury Road     6.0      10.0
# 74                                        Gladiator     5.0      12.0
# 103                        The Silence of the Lambs     5.0       7.0
# 201                         Raiders of the Lost Ark     5.0       9.0
# 113                             Saving Private Ryan     5.0      11.0
# 301                                      Braveheart     5.0      10.0
# 478                                            Hugo     5.0      11.0
# 763                                     The Aviator     5.0      11.0
# 210                                 American Beauty     5.0       8.0
# 1288                                     The Artist     5.0      10.0
# 3599                            Terms of Endearment     5.0      11.0

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Crear diccionario {título: número de premios}
frecuencias = dict(zip(
    pelis[pelis['awards'] >= 5]['title'],
    pelis[pelis['awards'] >= 5]['awards'].astype(int)
))

# Crear wordcloud
wc = WordCloud(
    background_color='#00002e',
    width=1200,
    height=600,
    colormap='YlOrBr',
    max_font_size=150,
    min_font_size=20,
    prefer_horizontal=0.9
).generate_from_frequencies(frecuencias)

fig, ax = plt.subplots(figsize=(14, 7), facecolor='#00002e')
ax.imshow(wc, interpolation='bilinear')
ax.axis('off')


plt.tight_layout()
plt.show()

# %%
# Vamos a ver si hay diferencias significativas o cosas en común entre los grandes triunfadores
big_ones = pelis [pelis["awards"] >= 3]
rest = pelis [pelis["awards"] < 3]

# %%
big_ones [['budget', 'revenue', 'ROI', 'averageRating', 'runtime']].describe()
# Out:
#              budget       revenue        ROI  averageRating     runtime
# count  9.000000e+01  9.000000e+01  90.000000      90.000000   90.000000
# mean   5.065403e+07  3.426442e+08   9.158546      78.933333  136.122222
# std    5.413502e+07  4.340673e+08   9.406289       5.049864   26.416639
# min    3.000000e+06  1.140769e+06   0.076051      62.000000   91.000000
# 25%    1.500000e+07  9.961132e+07   3.636751      75.000000  119.000000
# 50%    2.500000e+07  2.208420e+08   6.841174      79.000000  129.500000
# 75%    7.000000e+07  4.217095e+08  12.212874      82.000000  150.750000
# max    2.370000e+08  2.923706e+09  75.520524      90.000000  201.000000

# %%
rest [['budget', 'revenue', 'ROI', 'averageRating','runtime']].describe()
# Out:
#              budget       revenue          ROI  averageRating      runtime
# count  7.934000e+03  7.934000e+03  7934.000000    7934.000000  7934.000000
# mean   2.607564e+07  7.106916e+07     4.586408      62.908621   108.236451
# std    3.755964e+07  1.538012e+08    50.935673      10.910744    23.156515
# min    1.000000e+04  5.000000e+03     0.000256      11.000000     0.000000
# 25%    4.000000e+06  2.775671e+06     0.589957      57.000000    94.000000
# 50%    1.245447e+07  1.688634e+07     1.673495      64.000000   105.000000
# 75%    3.000000e+07  6.791399e+07     3.558498      70.000000   120.000000
# max    3.790000e+08  2.800000e+09  4143.984983      95.000000   339.000000

# %%
#Hay ceros en la duración de películas en resto .... cuantos? 
print((rest['runtime'] == 0).sum())
# Out:
# 41

# %%
# Compruebo visualmente a qué corresponden las películas con duraciones menores de 10
# El 1 eran errores pero  el resto de longitudes menores de 10 minutos corresponden a cortos
rest[rest['runtime'] < 10]
# Out:
#            id                                              title    status  \
# 4359    13927                                            Tin Toy  Released
# 7062   412795                                            Maligno  Released
# 7258    92384                             Trois 2: Pandora's Box  Released
# 7332   268898                                      The Candidate  Released
# 7361    41894                            Blood Done Sign My Name  Released
# 7365    71245                                         Tender May  Released
# 7393   348750                                          8 Seconds  Released
# 7417   109045                                        Firecrosser  Released
# 7560   636322                          FOMO: Fear of Missing Out  Released
# 7592   328337                        Galis: The Journey to Astra  Released
# 7625   486888                      Linklater: On Cinema and Time  Released
# 7643   114564                           Shikshanachya Aaicha Gho  Released
# 7730   422051                                            VITRIOL  Released
# 7735   309303                                Todo menos la chica  Released
# 7739   351300                                     City of Mice 2  Released
# 7796   462702                                     Hands together  Released
# 7816   883927                           Estremecer, Lejos de ti.  Released
# 7820   586055                           Las llaves de la memoria  Released
# 7821   892739  Nanna & Lil' Puss Puss in 'Who Calcutta the Ch...  Released
# 7822   892749    Science Please! : The Wonderful World of Colour  Released
# 7823   576796                                            Именины  Released
# 7826   509244                     From My Window, Without a Home  Released
# 7836  1431894                         Uncharted 4: A thief's End  Released
# 7837  1431894                         Uncharted 4: A thief's End  Released
# 7857   309174                     Mayday! Überfall auf hoher See  Released
# 7869  1038943                                           买买提的2008  Released
# 7876    77755                                       Det' jo løgn  Released
# 7879   402557                                  Paths of the Gods  Released
# 7885    73950                              Eski Açık Sarı Desene  Released
# 7897  1220088                                      Rastgele Orsa  Released
# 7898  1271337                                               EDDY  Released
# 7899  1266829                            Shift-e Nimeh Shab 2016  Released
# 7914   597792                                              Damga  Released
# 7915   603748                                         Ненасытные  Released
# 7921   499735                                         Aadhi Raat  Released
# 7936   547488                               Two Syllables Behind  Released
# 7943   692712                                  Tres Escapularios  Released
# 7946   679670                           Rescue Me: A Home 4 Spot  Released
# 7949   671911                                    Chaal Gazab Hai  Released
# 7956   617952                                       Tattoo Girls  Released
# 7977   453248                       Monkey King vs. Er Lang Shen  Released
# 7997   960175                               Karmafal Daata Shani  Released
# 8002   790305                               Adventure of a Panda  Released
# 8005   821114                                     Doh Doh Island  Released
# 8010   897721                                           EU & USA  Released
# 8012   896920                                         Say Cheese  Released
# 8013   877760                 George and Junior - Look Out Below  Released
# 8015   921377                                          Helal Süt  Released
# 8017   905057                               Les Baltus Au Cirque  Released
# 8018   905063               Science Please! : The Force of Water  Released
# 8019   904112   Science Please! : The Internal Combustion Engine  Released
# 8020   906233                                Pizza Boy in No Tip  Released
# 8021   903093                                            BuzziN'  Released
# 8022   911490                                       Chromosaurus  Released
#
#      release_date     revenue  runtime  adult     budget     imdb_id  \
# 4359   01/08/1988      123967        5  FALSO     300000   tt0096273
# 7062   14/07/2016      400000        0  FALSO     150000   tt5722530
# 7258   09/08/2002      833779        0  FALSO     800000   tt0285869
# 7332   10/10/2013      540000        0  FALSO     250000   tt3258080
# 7361   01/02/2010       82739        0  FALSO   10000000   tt1210039
# 7365   01/10/2009     1630907        0  FALSO    4500000   tt1505886
# 7393   27/02/2015     1759935        0  FALSO    5556000   tt4158834
# 7417   19/01/2012      174000        0  FALSO    2000000   tt1927035
# 7560   10/10/2019       78254        0  FALSO     208000   tt7718114
# 7592   07/08/2014     2700000        0  FALSO    1400000   tt4901934
# 7625   04/12/2013        9000        9  FALSO     100000   tt6813504
# 7643   15/01/2010      520000        0  FALSO     380000   tt2321513
# 7730   05/11/2012       83077        0  FALSO     300000   tt2520926
# 7735   19/02/2002       93059        0  FALSO    1200000   tt0262050
# 7739   25/08/2014     4000000        0  FALSO    2500000   tt3507794
# 7796   21/10/2014       50000        0  FALSO     150000   tt4261452
# 7816   04/06/2018       10000        0  FALSO      10000  tt13129744
# 7820   11/10/2016       50000        0  FALSO      50000   tt7960962
# 7821   13/07/1993       15107        3  FALSO      15107   tt0360827
# 7822   08/05/1999      100270        1  FALSO     100270  tt13432980
# 7823   07/06/2004       72500        0  FALSO     600000   tt0418746
# 7826   17/03/2006      300000        0  FALSO    1000000   tt0810822
# 7836   10/05/2016  1000000000        0  FALSO  250000000   tt3334704
# 7837   10/05/2016  1000000000        0  FALSO  250000000   tt3334704
# 7857   09/08/2001      500000        0  FALSO     200000   tt0290759
# 7869   06/04/2008       20707        0  FALSO     414147   tt9536384
# 7876   22/03/2010      100000        0  FALSO      10000   tt0324770
# 7879   17/02/1995     4000000        0  FALSO    1000000   tt0125453
# 7885   10/10/2003      130392        0  FALSO     100000   tt0386438
# 7897   10/11/2012       50000        0  FALSO      20000   tt2882558
# 7898   23/09/2015     1000000        0  FALSO      50000   tt4625352
# 7899   02/06/2016       30000        0  FALSO      18000   tt8148198
# 7914   02/04/1987      105000        0  FALSO      55000   tt5547646
# 7915   31/08/2006     1320000        0  FALSO    1700000   tt3726526
# 7921   22/10/1999        5873        0  FALSO      15660   tt3713626
# 7936   01/02/2005       17696        0  FALSO     340000   tt0434246
# 7943   13/03/2015        5152        0  FALSO     200000   tt5761968
# 7946   08/10/2019       50000        0  FALSO      25000  tt10918524
# 7949   27/05/2019       15000        0  FALSO      10000  tt10319732
# 7956   01/04/2018      101211        0  FALSO      21000   tt5601424
# 7977   16/02/2007      910000        0  FALSO    1200000   tt1619890
# 7997   09/03/2018    10000000        0  FALSO  100000000   tt8437668
# 8002   26/01/1982     2000000        0  FALSO    1000000   tt0334737
# 8005   01/06/2003      500000        0  FALSO      50000   tt1097560
# 8010   13/08/2018      157202        5  FALSO     157202   tt8840490
# 8012   01/02/2000       21515        1  FALSO      21515   tt0875616
# 8013   23/07/1995       14217        7  FALSO      14217   tt1132586
# 8015   01/01/2013      100000        0  FALSO     100000   tt6566142
# 8017   20/08/1999       27378        6  FALSO      27378   tt0354400
# 8018   01/01/1998       43134        1  FALSO      43134   tt0238991
# 8019   01/01/2000      300996        1  FALSO     300996   tt0308599
# 8020   25/02/1996       61661        7  FALSO      61661   tt1516467
# 8021   01/09/2017     1747037        5  FALSO    1747037   tt7650604
# 8022   31/07/1985       65993        1  FALSO      65993   tt0345041
#
#      original_language  ... averageRating    year  nominees  awards  \
# 4359                en  ...            64  1988.0       1.0     1.0
# 7062                es  ...            49  2016.0       0.0     0.0
# 7258                en  ...            48  2002.0       0.0     0.0
# 7332                sk  ...            68  2013.0       0.0     0.0
# 7361                en  ...            65  2010.0       0.0     0.0
# 7365                ru  ...            62  2009.0       0.0     0.0
# 7393                de  ...            63  2015.0       0.0     0.0
# 7417                uk  ...            69  2012.0       0.0     0.0
# 7560                hu  ...            66  2019.0       0.0     0.0
# 7592                he  ...            55  2014.0       0.0     0.0
# 7625                en  ...            77  2013.0       0.0     0.0
# 7643                mr  ...            71  2010.0       0.0     0.0
# 7730                it  ...            68  2012.0       0.0     0.0
# 7735                es  ...            44  2002.0       0.0     0.0
# 7739                fa  ...            62  2014.0       0.0     0.0
# 7796                es  ...            89  2014.0       0.0     0.0
# 7816                es  ...            90  2018.0       0.0     0.0
# 7820                es  ...            80  2016.0       0.0     0.0
# 7821                en  ...            82  1993.0       0.0     0.0
# 7822                en  ...            70  1999.0       0.0     0.0
# 7823                ru  ...            66  2004.0       0.0     0.0
# 7826                fr  ...            59  2006.0       0.0     0.0
# 7836                en  ...            94  2016.0       0.0     0.0
# 7837                en  ...            94  2016.0       0.0     0.0
# 7857                de  ...            35  2001.0       0.0     0.0
# 7869                zh  ...            68  2008.0       0.0     0.0
# 7876                da  ...            72  2010.0       0.0     0.0
# 7879                en  ...            78  1995.0       0.0     0.0
# 7885                tr  ...            75  2003.0       0.0     0.0
# 7897                tr  ...            87  2012.0       0.0     0.0
# 7898                it  ...            95  2015.0       0.0     0.0
# 7899                fa  ...            64  2016.0       0.0     0.0
# 7914                tr  ...            44  1987.0       0.0     0.0
# 7915                ru  ...            32  2006.0       0.0     0.0
# 7921                hi  ...            52  1999.0       0.0     0.0
# 7936                sk  ...            71  2005.0       0.0     0.0
# 7943                es  ...            71  2015.0       0.0     0.0
# 7946                en  ...            84  2019.0       0.0     0.0
# 7949                en  ...            86  2019.0       0.0     0.0
# 7956                pl  ...            82  2018.0       0.0     0.0
# 7977                zh  ...            49  2007.0       0.0     0.0
# 7997                ru  ...            86  2018.0       0.0     0.0
# 8002                zh  ...            63  1982.0       0.0     0.0
# 8005                es  ...            90  2003.0       0.0     0.0
# 8010                en  ...            60  2018.0       0.0     0.0
# 8012                en  ...            58  2000.0       0.0     0.0
# 8013                en  ...            68  1995.0       0.0     0.0
# 8015                tr  ...            83  2013.0       0.0     0.0
# 8017                en  ...            72  1999.0       0.0     0.0
# 8018                en  ...            64  1998.0       0.0     0.0
# 8019                en  ...            70  2000.0       0.0     0.0
# 8020                en  ...            78  1996.0       0.0     0.0
# 8021                en  ...            60  2017.0       0.0     0.0
# 8022                en  ...            66  1985.0       0.0     0.0
#
#             ROI  nominadas    budget_M    revenue_M  rating_categoria  count
# 4359   0.413223       True    0.300000     0.123967             Media    NaN
# 7062   2.666667      False    0.150000     0.400000              Baja    NaN
# 7258   1.042224      False    0.800000     0.833779              Baja    NaN
# 7332   2.160000      False    0.250000     0.540000              Alta    NaN
# 7361   0.008274      False   10.000000     0.082739             Media    NaN
# 7365   0.362424      False    4.500000     1.630907             Media    NaN
# 7393   0.316763      False    5.556000     1.759935             Media    NaN
# 7417   0.087000      False    2.000000     0.174000              Alta    NaN
# 7560   0.376221      False    0.208000     0.078254              Alta    NaN
# 7592   1.928571      False    1.400000     2.700000             Media    NaN
# 7625   0.090000      False    0.100000     0.009000          Muy alta    NaN
# 7643   1.368421      False    0.380000     0.520000              Alta    NaN
# 7730   0.276923      False    0.300000     0.083077              Alta    NaN
# 7735   0.077549      False    1.200000     0.093059              Baja    NaN
# 7739   1.600000      False    2.500000     4.000000             Media    NaN
# 7796   0.333333      False    0.150000     0.050000          Muy alta    NaN
# 7816   1.000000      False    0.010000     0.010000          Muy alta    NaN
# 7820   1.000000      False    0.050000     0.050000          Muy alta    NaN
# 7821   1.000000      False    0.015107     0.015107          Muy alta    NaN
# 7822   1.000000      False    0.100270     0.100270              Alta    NaN
# 7823   0.120833      False    0.600000     0.072500              Alta    NaN
# 7826   0.300000      False    1.000000     0.300000             Media    NaN
# 7836   4.000000      False  250.000000  1000.000000          Muy alta    NaN
# 7837   4.000000      False  250.000000  1000.000000          Muy alta    NaN
# 7857   2.500000      False    0.200000     0.500000              Baja    NaN
# 7869   0.049999      False    0.414147     0.020707              Alta    NaN
# 7876  10.000000      False    0.010000     0.100000              Alta    NaN
# 7879   4.000000      False    1.000000     4.000000          Muy alta    NaN
# 7885   1.303920      False    0.100000     0.130392              Alta    NaN
# 7897   2.500000      False    0.020000     0.050000          Muy alta    NaN
# 7898  20.000000      False    0.050000     1.000000          Muy alta    NaN
# 7899   1.666667      False    0.018000     0.030000             Media    NaN
# 7914   1.909091      False    0.055000     0.105000              Baja    NaN
# 7915   0.776471      False    1.700000     1.320000              Baja    NaN
# 7921   0.375032      False    0.015660     0.005873             Media    NaN
# 7936   0.052047      False    0.340000     0.017696              Alta    NaN
# 7943   0.025760      False    0.200000     0.005152              Alta    NaN
# 7946   2.000000      False    0.025000     0.050000          Muy alta    NaN
# 7949   1.500000      False    0.010000     0.015000          Muy alta    NaN
# 7956   4.819571      False    0.021000     0.101211          Muy alta    NaN
# 7977   0.758333      False    1.200000     0.910000              Baja    NaN
# 7997   0.100000      False  100.000000    10.000000          Muy alta    NaN
# 8002   2.000000      False    1.000000     2.000000             Media    NaN
# 8005  10.000000      False    0.050000     0.500000          Muy alta    NaN
# 8010   1.000000      False    0.157202     0.157202             Media    NaN
# 8012   1.000000      False    0.021515     0.021515             Media    NaN
# 8013   1.000000      False    0.014217     0.014217              Alta    NaN
# 8015   1.000000      False    0.100000     0.100000          Muy alta    NaN
# 8017   1.000000      False    0.027378     0.027378              Alta    NaN
# 8018   1.000000      False    0.043134     0.043134             Media    NaN
# 8019   1.000000      False    0.300996     0.300996              Alta    NaN
# 8020   1.000000      False    0.061661     0.061661          Muy alta    NaN
# 8021   1.000000      False    1.747037     1.747037             Media    NaN
# 8022   1.000000      False    0.065993     0.065993              Alta    NaN
#
# [54 rows x 22 columns]

# %%
rest = rest [rest['runtime'] > 1]

# %%
#Recalculo
big_ones [['budget', 'revenue', 'ROI', 'averageRating', 'runtime']].describe()
# Out:
#              budget       revenue        ROI  averageRating     runtime
# count  9.000000e+01  9.000000e+01  90.000000      90.000000   90.000000
# mean   5.065403e+07  3.426442e+08   9.158546      78.933333  136.122222
# std    5.413502e+07  4.340673e+08   9.406289       5.049864   26.416639
# min    3.000000e+06  1.140769e+06   0.076051      62.000000   91.000000
# 25%    1.500000e+07  9.961132e+07   3.636751      75.000000  119.000000
# 50%    2.500000e+07  2.208420e+08   6.841174      79.000000  129.500000
# 75%    7.000000e+07  4.217095e+08  12.212874      82.000000  150.750000
# max    2.370000e+08  2.923706e+09  75.520524      90.000000  201.000000

# %%
rest [['budget', 'revenue', 'ROI', 'averageRating','runtime']].describe()
# Out:
#              budget       revenue          ROI  averageRating      runtime
# count  7.888000e+03  7.888000e+03  7888.000000    7888.000000  7888.000000
# mean   2.614680e+07  7.122564e+07     4.601065      62.875254   108.867013
# std    3.744415e+07  1.534482e+08    51.082969      10.870104    21.697084
# min    1.000000e+04  5.000000e+03     0.000256      11.000000     3.000000
# 25%    4.000000e+06  2.852658e+06     0.591905      57.000000    94.000000
# 50%    1.250000e+07  1.708631e+07     1.679073      64.000000   105.000000
# 75%    3.100000e+07  6.835168e+07     3.563244      70.000000   120.000000
# max    3.790000e+08  2.800000e+09  4143.984983      95.000000   339.000000

# %% [markdown]
# En todos los valores parece que hay diferencias notables:
# - Big ones tienen de media el doble de presupuesto
# - Pero también recaudan más: casi 5 veces más
# - Son casi el doble de rentables
# - Curiosamente tienden a ser más largas, casi media hora más de media
# - Mucho mejor valoradas. Esto ya lo habíamos visto

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

metricas = ['budget', 'revenue', 'ROI', 'averageRating']
titulos = ['Presupuesto medio', 'Recaudación media', 'ROI medio', 'Valoración media']
colores = ['#B0C4DE', '#4A7FB5']

for ax, metrica, titulo in zip(axes.flatten(), metricas, titulos):
    valores = [rest[metrica].mean(), big_ones[metrica].mean()]
    sns.barplot(x=['Resto', 'Grandes ganadores'], y=valores, palette=colores, ax=ax)
    ax.set_title(titulo)
    ax.set_xlabel('')

plt.suptitle('Grandes ganadores vs resto de películas', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\NaiaJon\AppData\Local\Temp\ipykernel_11500\1840232997.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Resto', 'Grandes ganadores'], y=valores, palette=colores, ax=ax)
# C:\Users\NaiaJon\AppData\Local\Temp\ipykernel_11500\1840232997.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Resto', 'Grandes ganadores'], y=valores, palette=colores, ax=ax)
# C:\Users\NaiaJon\AppData\Local\Temp\ipykernel_11500\1840232997.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Resto', 'Grandes ganadores'], y=valores, palette=colores, ax=ax)
# C:\Users\NaiaJon\AppData\Local\Temp\ipykernel_11500\1840232997.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Resto', 'Grandes ganadores'], y=valores, palette=colores, ax=ax)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

metricas = ['budget', 'revenue', 'ROI', 'averageRating']
titulos = ['Presupuesto medio', 'Recaudación media', 'ROI medio', 'Valoración media']

fig = make_subplots(rows=2, cols=2, subplot_titles=titulos)

posiciones = [(1,1), (1,2), (2,1), (2,2)]

for (row, col), metrica in zip(posiciones, metricas):
    
    fig.add_trace(go.Bar(
        x=['Resto', 'Grandes ganadores'],
        y=[rest[metrica].mean(), big_ones[metrica].mean()],
        marker_color=['#B0C4DE', '#4A7FB5'],
        showlegend=False
    ), row=row, col=col)

fig.update_layout(
    title=dict(text='Grandes ganadores vs resto de películas', font=dict(size=16)),
    height=600,
    width=900,
    template='plotly_white',
    font=dict(family='Arial')
)

fig.show()

# %%
rest['budget_M'] = rest['budget'] / 1e6
rest['revenue_M'] = rest['revenue'] / 1e6
big_ones ['budget_M'] = big_ones ['budget']/ 1e6
big_ones['revenue_M'] = big_ones ['revenue'] / 1e6

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10), facecolor='#00002e')

metricas = ['budget_M', 'revenue_M', 'ROI', 'averageRating']
titulos = ['Presupuesto medio (mill $)', 'Recaudación media (mill $)', 'ROI medio', 'Valoración media']
colores = ['#4A90D9', '#F5A623']

for ax, metrica, titulo in zip(axes.flatten(), metricas, titulos):
    valores = [rest[metrica].mean(), big_ones[metrica].mean()]
    grupos = ['Resto', 'Grandes ganadores']
    ax.set_facecolor('#00002e')
    sns.barplot(x=grupos, y=valores, hue=grupos, palette=colores, 
                legend=False, ax=ax)
    ax.set_title(titulo, color='white')
    ax.set_xlabel('')
    ax.tick_params(colors='white')
    ax.xaxis.label.set_color('white')
    ax.yaxis.label.set_color('white')
    plt.setp(ax.spines.values(), color='#00002e')

plt.suptitle('Grandes ganadores vs resto de películas', 
             fontsize=14, color='white')
plt.tight_layout()
plt.show()

# %%
# 
import plotly.graph_objects as go
import pandas as pd

# 1. PREPARACIÓN DE LOS DATOS (Calculamos las medias de tus dos DF)
datos_resumen = {
    'Grupo': ['Grandes Ganadores', 'Resto'],
    'Presupuesto': [big_ones['budget_M'].mean(), rest['budget_M'].mean()],
    'Recaudacion': [big_ones['revenue_M'].mean(), rest['revenue_M'].mean()]
}
df_conclusiones = pd.DataFrame(datos_resumen)

# --- CONFIGURACIÓN DE COLORES 'CINE ORBIT' ---
# Dorado para Ganadoras, Gris/Azulado para el Resto
paleta = ['#D4AF37', '#4A90D9'] 
 #paleta = ['#4A90D9', '#F5A623']

# --- CREACIÓN DEL GRÁFICO ---
fig = go.Figure()

# Barra de Recaudación (La más larga, va detrás)
fig.add_trace(go.Bar(
    y=df_conclusiones['Grupo'],
    x=df_conclusiones['Recaudacion'],
    name='Recaudación',
    orientation='h',
    marker=dict(color=paleta[0], line=dict(color=paleta[0], width=1)),
    hovertemplate='Recaudación: %{x:.1f} M$<extra></extra>',
    text=[f"  {v:.1f} M$ Recaudación" for v in df_conclusiones['Recaudacion']],
    textposition='outside',
    textfont=dict(color=paleta[0], size=14)
))

# Barra de Presupuesto (La más corta, se superpone delante)
fig.add_trace(go.Bar(
    y=df_conclusiones['Grupo'],
    x=df_conclusiones['Presupuesto'],
    name='Presupuesto',
    orientation='h',
    marker=dict(color='#cbd5e1', opacity=0.8), # Gris claro para que contraste
    hovertemplate='Inversión: %{x:.1f} M$<extra></extra>',
    text=[f" {v:.1f} M$ Inversión" for v in df_conclusiones['Presupuesto']],
    textposition='inside',
    textfont=dict(color='#0b1120', size=12) # Texto oscuro dentro de la barra clara
))

# --- AJUSTES DE DISEÑO PARA POWERPOINT (ORBIT) ---
fig.update_layout(
    barmode='overlay', # Superposición para ver cuánto "crece" la inversión
    template='plotly_dark',
    paper_bgcolor='rgba(0,0,0,0)', # Transparente para tu fondo azul oscuro
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="Arial, sans-serif",
    title_text="Inversión vs Recaudación",
    title_font=dict(size=24, color='#cbd5e1'),
    margin=dict(l=150, r=150, t=80, b=40),
    xaxis=dict(
        showgrid=False, 
        zeroline=False, 
        showticklabels=False, 
        range=[0, df_conclusiones['Recaudacion'].max() * 1.3] # Espacio para el texto
    ),
    yaxis=dict(
        title=None, 
        tickfont=dict(size=16, color='white'),
        categoryorder='total ascending' # Pone los Ganadores arriba
    ),
    showlegend=False,
    height=400
)

fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# --- CONFIGURACIÓN DE DATOS (Basado en tu código) ---
metricas = ['budget_M', 'revenue_M', 'ROI', 'averageRating']
titulos = ['Presupuesto (Mill $)', 'Recaudación (Mill $)', 'ROI (Retorno)', 'Valoración (1-100)']
colores = ['#4A90D9', '#D4AF37'] # Azul suave y Dorado Premios

# --- CREACIÓN DEL DASHBOARD ---
fig = make_subplots(
    rows=2, cols=2, 
    subplot_titles=titulos,
    vertical_spacing=0.15,
    horizontal_spacing=0.1
)

for i, (metrica, titulo) in enumerate(zip(metricas, titulos)):
    row = (i // 2) + 1
    col = (i % 2) + 1
    
    valores = [rest[metrica].mean(), big_ones[metrica].mean()]
    grupos = ['Resto', 'Grandes Ganadores']
    
    # Añadimos las barras
    fig.add_trace(
        go.Bar(
            x=grupos,
            y=valores,
            marker_color=colores,
            text=[f"{v:.1f}" for v in valores], # Etiquetas de datos sobre las barras
            textposition='auto',
            name=titulo,
            showlegend=False
        ),
        row=row, col=col
    )

# --- ESTILO "ORBIT" PARA POWERPOINT ---
fig.update_layout(
    # Fondo transparente para que se funda con tu PowerPoint
    paper_bgcolor='rgba(0,0,0,0)', 
    plot_bgcolor='rgba(0,0,0,0)',
    
    # Tipografía y colores de títulos
    font=dict(family="Arial, sans-serif", size=14, color="white"),
    height=700,
    width=900,
    margin=dict(t=100, b=50, l=50, r=50)
)

# Limpieza de ejes (estética minimalista)
fig.update_xaxes(showgrid=False, zeroline=False, color="white")
fig.update_yaxes(showgrid=True, gridcolor="#1e293b", zeroline=False, color="white")

# Personalización de los títulos de los subplots
for i in fig['layout']['annotations']:
    i['font'] = dict(size=18, color="#D4AF37")

fig.show()

# OPCIONAL: Guardar como imagen para pegar en tu PPT
# fig.write_image("conclusiones_cine.png", scale=3)

# %%
#Géneros?
big_ones['genre'].value_counts(normalize=True)*100
# Out:
# genre
# Drama              50.000000
# Adventure          11.111111
# Action             10.000000
# Comedy              8.888889
# Fantasy             3.333333
# History             3.333333
# Western             2.222222
# War                 2.222222
# Crime               2.222222
# Science Fiction     2.222222
# Romance             2.222222
# Music               1.111111
# Thriller            1.111111
# Name: proportion, dtype: float64

# %%
#Es la misma proporción que en el resto?
rest['genre'].value_counts (normalize=True)*100
# Out:
# genre
# Drama              23.136410
# Comedy             22.413793
# Action             15.314402
# Horror              6.528905
# Adventure           5.768256
# Thriller            4.513185
# Crime               4.462475
# Romance             3.105984
# Animation           2.953854
# Fantasy             2.370690
# Science Fiction     2.256592
# Family              2.117140
# Documentary         1.229716
# Mystery             1.064909
# Music               0.925456
# War                 0.887424
# History             0.608519
# Western             0.329615
# TV Movie            0.012677
# Name: proportion, dtype: float64

# %%
genre_pct = big_ones['genre'].value_counts(normalize=True).mul(100).reset_index()
genre_pct.columns = ['genre', 'pct']
sns.barplot(data=genre_pct, x='pct', y='genre')
plt.xlabel ('Porcentaje')
plt.ylabel ('Género')
# Out:
# Text(0, 0.5, 'Género')

# %%
genre_pct = rest['genre'].value_counts(normalize=True).mul(100).reset_index()
genre_pct.columns = ['genre', 'pct']
sns.barplot(data=genre_pct, x='pct', y='genre')
plt.xlabel ('Porcentaje')
plt.ylabel ('Género')
# Out:
# Text(0, 0.5, 'Género')

# %%
# Drama domina de forma muy aplastante: 50% vs 23% en el resto. Una de cada dos películas con 3+ Oscars es un drama.
# Horror casi desaparece: 6.5% en el resto pero ni aparece entre los grandes ganadores.Lo habíamos visto ya. No se premia
# Comedy cae a la mitad: 22% del resto vs 9% entre grandes ganadores. Las comedias no ganan Oscars.
